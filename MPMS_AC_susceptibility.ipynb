# %% [markdown]
# # Plot MPMS AC susceptibility data
#
# This notebook visualizes data from low-temperature experiments conducted on an MPMS instrument and exported to MagIC format.
#
# **MPMS AC in phase and out of phase susceptibility vs temperature**

# %% [markdown]
# ## Import scientific python libraries
#
# Run the cell below to import the functions needed for the notebook.

# %%
import rockmag as rmag
import pmagpy.contribution_builder as cb
import pmagpy.ipmag as ipmag

import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

import ipywidgets as widgets

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Import data
#
# We can take the same approach as in the `rockmag_data_unpack.ipynb` notebook to bring the MagIC data into the notebook as a Contribution. To bring in a different contribution, set the directory path (currently `'./example_data/SSRM2022C'`) and the share key for your MagIC contribution which you can find by clicking on the "Share" button in the MagIC database.
#
# <figure>
#   <img src="book/images/MagIC_private_contribution_1.png" alt="Description of the image" width="800">
# </figure>
#
# copy the share key highlighted in grey in the following image to the `share_key` variable in the cell below.
# <figure>
#   <img src="book/images/MagIC_private_contribution_2.png" alt="Description of the image" width="800">
# </figure>
#
# **change the directory path and file name in the cell below to load your own data**

# %%
#define these three parameters to match your data
magic_id = '20100'
share_key = '1068543b-13d5-4b7b-9069-cc35de784e38'
dir_path = 'example_data/SSRM2022C'

result, magic_file = ipmag.download_magic_from_id(magic_id, directory=dir_path, share_key=share_key)
ipmag.unpack_magic(magic_file, dir_path)
contribution = cb.Contribution(dir_path)
measurements = contribution.tables['measurements'].df
measurements.dropna(axis=1, how='all')
# Out:
# Download successful. File saved to: example_data/SSRM2022C/magic_contribution_20100.txt
# working on:  'contribution'
# 1  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/contribution.txt
# contribution  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/contribution.txt
# working on:  'locations'
# 6  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/locations.txt
# locations  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/locations.txt
# working on:  'sites'
# 6  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/sites.txt
# sites  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/sites.txt
# working on:  'samples'
# 16  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/samples.txt
# samples  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/samples.txt
# working on:  'specimens'
# 47  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/specimens.txt
# specimens  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/specimens.txt
# working on:  'measurements'
# 141061  records written to file  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/measurements.txt
# measurements  data put in  /Users/yimingzhang/Github/RockmagPy-notebooks/example_data/SSRM2022C/measurements.txt
# -I- Using online data model
# -I- Getting method codes from earthref.org
# -I- Importing controlled vocabularies from https://earthref.org
#                                                dir_dec    dir_inc  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1         NaN        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2         NaN        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3         NaN        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4         NaN        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5         NaN        NaN
# ...                                                ...        ...
# nan                                          89.287256  69.154282
# nan                                          89.179101 -46.279529
# nan                                          78.668498 -42.932098
# nan                                        -263.526376  41.525431
# nan                                        -256.886343  65.097030
#
#                                                                      experiment  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1   IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2   IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3   IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4   IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5   IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667
# ...                                                                         ...
# nan                                                DX1-4b-ARM_aniso-LP-AN-ARM-0
# nan                                                DA4-1C-ARM_aniso-LP-AN-ARM-0
# nan                                                DX1-4b-ARM_aniso-LP-AN-ARM-0
# nan                                         DA4-1C-ARMdemag(T,Hac)-LP-ARM-AFD-0
# nan                                         DX1-4b-ARMdemag(T,Hac)-LP-ARM-AFD-0
#
#                                            instrument_codes  magn_mass  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1        IRM-MPMS3        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2        IRM-MPMS3        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3        IRM-MPMS3        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4        IRM-MPMS3        NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5        IRM-MPMS3        NaN
# ...                                                     ...        ...
# nan                                               IRM-SRM-U        NaN
# nan                                               IRM-SRM-U        NaN
# nan                                               IRM-SRM-U        NaN
# nan                                               IRM-SRM-U        NaN
# nan                                               IRM-SRM-U        NaN
#
#                                              magn_moment  magn_r2_det  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1           NaN          NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2           NaN          NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3           NaN          NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4           NaN          NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5           NaN          NaN
# ...                                                  ...          ...
# nan                                         6.020000e-08          NaN
# nan                                         5.570000e-06          NaN
# nan                                         2.990000e-07          NaN
# nan                                         2.340000e-07          NaN
# nan                                         5.570000e-08          NaN
#
#                                                   magn_x        magn_y  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1           NaN           NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2           NaN           NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3           NaN           NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4           NaN           NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5           NaN           NaN
# ...                                                  ...           ...
# nan                                         2.660000e-10  2.140000e-08
# nan                                         5.510000e-08  3.850000e-06
# nan                                         4.300000e-08  2.150000e-07
# nan                                        -1.970000e-08  1.740000e-07
# nan                                        -5.320000e-09  2.280000e-08
#
#                                                   magn_z  meas_field_ac  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1           NaN         0.0003
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2           NaN         0.0003
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3           NaN         0.0003
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4           NaN         0.0003
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5           NaN         0.0003
# ...                                                  ...            ...
# nan                                         5.620000e-08            NaN
# nan                                        -4.020000e-06            NaN
# nan                                        -2.040000e-07            NaN
# nan                                         1.550000e-07            NaN
# nan                                         5.050000e-08            NaN
#
#                                             meas_field_dc  meas_freq  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1            NaN       1.00
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2            NaN       5.32
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3            NaN      28.26
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4            NaN     150.47
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5            NaN     800.46
# ...                                                   ...        ...
# nan                                                   NaN        NaN
# nan                                                   NaN        NaN
# nan                                                   NaN        NaN
# nan                                                   NaN        NaN
# nan                                                   NaN        NaN
#
#                                             meas_pos_z  meas_temp  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1         NaN       10.0
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2         NaN       10.0
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3         NaN       10.0
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4         NaN       10.0
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5         NaN       10.0
# ...                                                ...        ...
# nan                                               0.25        NaN
# nan                                               0.05        NaN
# nan                                               0.25        NaN
# nan                                               0.05        NaN
# nan                                               0.25        NaN
#
#                                                                            measurement  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5
# ...                                                                                ...
# nan                                                                               None
# nan                                                                               None
# nan                                                                               None
# nan                                                                               None
# nan                                                                               None
#
#                                                   method_codes quality  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1  LP-X:LP-X-T:LP-X-F       g
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2  LP-X:LP-X-T:LP-X-F       g
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3  LP-X:LP-X-T:LP-X-F       g
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4  LP-X:LP-X-T:LP-X-F       g
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5  LP-X:LP-X-T:LP-X-F       g
# ...                                                        ...     ...
# nan                                                  LP-AN-ARM    None
# nan                                                  LP-AN-ARM    None
# nan                                                  LP-AN-ARM    None
# nan                                                 LP-ARM-AFD    None
# nan                                                 LP-ARM-AFD    None
#
#                                             sequence specimen standard  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1       1.0    DA4-r        u
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2       2.0    DA4-r        u
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3       3.0    DA4-r        u
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4       4.0    DA4-r        u
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5       5.0    DA4-r        u
# ...                                              ...      ...      ...
# nan                                              NaN   DX1-4b     None
# nan                                              NaN   DA4-1C     None
# nan                                              NaN   DX1-4b     None
# nan                                              NaN   DA4-1C     None
# nan                                              NaN   DX1-4b     None
#
#                                             susc_chi_mass  susc_chi_qdr_mass  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1   6.320000e-07       1.350000e-09
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2   6.300000e-07       1.500000e-09
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3   6.320000e-07       9.640000e-10
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4   6.300000e-07       1.550000e-09
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5   6.400000e-07      -5.730000e-09
# ...                                                   ...                ...
# nan                                                   NaN                NaN
# nan                                                   NaN                NaN
# nan                                                   NaN                NaN
# nan                                                   NaN                NaN
# nan                                                   NaN                NaN
#
#                                                          timestamp  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1  2024:05:29:09:35:19.00
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2  2024:05:29:09:35:19.00
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3  2024:05:29:09:35:19.00
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4  2024:05:29:09:35:19.00
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5  2024:05:29:09:35:19.00
# ...                                                            ...
# nan                                         2022:06:14:17:01:41.00
# nan                                         2022:06:14:17:09:04.00
# nan                                         2022:06:14:17:09:25.00
# nan                                         2022:06:14:17:19:07.00
# nan                                         2022:06:14:17:19:28.00
#
#                                             treat_ac_field  treat_dc_field  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1             NaN             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2             NaN             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3             NaN             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4             NaN             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5             NaN             NaN
# ...                                                    ...             ...
# nan                                                    0.2         0.00000
# nan                                                    0.2         0.00005
# nan                                                    0.2         0.00005
# nan                                                    0.2             NaN
# nan                                                    0.2             NaN
#
#                                             treat_dc_field_phi  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1                 NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2                 NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3                 NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4                 NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5                 NaN
# ...                                                        ...
# nan                                                        0.0
# nan                                                      -45.0
# nan                                                      -45.0
# nan                                                        NaN
# nan                                                        NaN
#
#                                             treat_dc_field_theta  \
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1                   NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2                   NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3                   NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4                   NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5                   NaN
# ...                                                          ...
# nan                                                          0.0
# nan                                                         90.0
# nan                                                         90.0
# nan                                                          NaN
# nan                                                          NaN
#
#                                             treat_step_num
# measurement name
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4             NaN
# DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5             NaN
# ...                                                    ...
# nan                                                    NaN
# nan                                                    NaN
# nan                                                    NaN
# nan                                                    NaN
# nan                                                    NaN
#
# [141061 rows x 29 columns]

# %% [markdown]
# ## The project export contains data from all the experiments
#
# Each measurement in a MagIC measurements table has a `method_codes` value. These method codes come from a "controlled vocabulary" (https://www2.earthref.org/MagIC/method-codes).
#
# In the method codes used for the example contribution:
# - `LP` refers to lab protocol
# - `LP-X:LP-X-T:LP-X-F` refers to susceptibility vs. temperature and frequency experiments done on the MPMS

# %%
measurements.method_codes.unique()
# Out:
# array(['LP-X:LP-X-T:LP-X-F', 'LP-X:LP-X-T:LP-X-F:LP-X-H', 'LP-X-T',
#        'LP-HYS', 'LP-BCR-BF', 'LP-FORC', 'LP-FC', 'LP-ZFC',
#        'LP-CW-SIRM:LP-MC', 'LP-CW-SIRM:LP-MW', 'LP-DIR-AF', 'LP-AN-ARM',
#        'LP-ARM-AFD'], dtype=object)

# %% [markdown]
# ## Let's filter for the MPMS AC X-T data from your project export

# %%
# the .dropna(axis=1, how='all').reset_index(drop=1) code is used to remove columns that are all NaNs and reset the index
XT_measurements = measurements[measurements['method_codes'].str.contains('LP-X:LP-X-T:LP-X-F')].dropna(axis=1, how='all').reset_index(drop=1)
XT_measurements.head()
# Out:
#                            experiment instrument_codes  meas_field_ac  \
# 0  IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667        IRM-MPMS3         0.0003
# 1  IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667        IRM-MPMS3         0.0003
# 2  IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667        IRM-MPMS3         0.0003
# 3  IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667        IRM-MPMS3         0.0003
# 4  IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667        IRM-MPMS3         0.0003
#
#    meas_freq  meas_temp                                 measurement  \
# 0       1.00       10.0  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-1
# 1       5.32       10.0  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-2
# 2      28.26       10.0  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-3
# 3     150.47       10.0  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-4
# 4     800.46       10.0  DA4-r-IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667-5
#
#          method_codes quality  sequence specimen standard  susc_chi_mass  \
# 0  LP-X:LP-X-T:LP-X-F       g       1.0    DA4-r        u   6.320000e-07
# 1  LP-X:LP-X-T:LP-X-F       g       2.0    DA4-r        u   6.300000e-07
# 2  LP-X:LP-X-T:LP-X-F       g       3.0    DA4-r        u   6.320000e-07
# 3  LP-X:LP-X-T:LP-X-F       g       4.0    DA4-r        u   6.300000e-07
# 4  LP-X:LP-X-T:LP-X-F       g       5.0    DA4-r        u   6.400000e-07
#
#    susc_chi_qdr_mass               timestamp
# 0       1.350000e-09  2024:05:29:09:35:19.00
# 1       1.500000e-09  2024:05:29:09:35:19.00
# 2       9.640000e-10  2024:05:29:09:35:19.00
# 3       1.550000e-09  2024:05:29:09:35:19.00
# 4      -5.730000e-09  2024:05:29:09:35:19.00

# %% [markdown]
# ## Now let's select a specimen and its X-T experiment of interest
#
# - One could do multiple rounds of X-T experiments on the same specimen
# - so choose in the `first dropdown menu` the specimen of interest
# - the choose in the `second dropdown menu` the experiment of interest

# %%
specimen, experiment = rmag.interactive_specimen_experiment_selection(XT_measurements)
# Out:
# Dropdown(description='specimen:', options=('DA4-r', 'DX1-4r', 'DX1-5r'), value='DA4-r')
# Dropdown(description='Experiment:', options=('IRM-MPMS3-LP-X:LP-X-T:LP-X-F-14667',), value='IRM-MPMS3-LP-X:LP-…

# %%
selected_experiment = XT_measurements[(XT_measurements['specimen']==specimen.value) & 
                                      (XT_measurements['experiment']==experiment.value)].reset_index(drop=1)

# %% [markdown]
# ### plot in-phase X-T data

# %%
fig, ax = rmag.plot_MPMS_AC_X_T(selected_experiment, phase='in', figsize=(5,5))

# %% [markdown]
# ### plot out-of-phase X-T data

# %%
fig, ax = rmag.plot_MPMS_AC_X_T(selected_experiment, phase='out', figsize=(5,5))

# %% [markdown]
# ### plot in and out-of-phase X-T data together

# %%
fig, ax = rmag.plot_MPMS_AC_X_T(selected_experiment, phase='both', figsize=(12,6))

# %% [markdown]
# ## Save the plot
#
# Put the name of the file in the cell below. There are many available file formats for figures such as: `jpg`, `pdf`, `png`. Whatever you choose in the file name will be the file type.
#
# Set the `save_directory`. If you want it to be the folder that the notebook is in, set it to be `'.'`.

# %%
file_name = 'output.png'
save_directory = './example_data/SSRM2022C' 

file_path = save_directory + '/' + file_name
fig.savefig(file_path, dpi=300)
