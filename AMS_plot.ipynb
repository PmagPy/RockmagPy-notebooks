# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including pandas for data manipulation and ipmag for anisotropy of magnetic susceptibility analysis.

# %%
# Importing the required libraries
import pandas as pd
import pmagpy.ipmag as ipmag

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Anisotropy of Magnetic Susceptibility Data
# Load the anisotropy of magnetic susceptibility data from a file using pandas.

# %%
specimen_file = 'sed_specimens.txt'
dir_path = 'example_data/AMS'

ipmag.aniso_magic(infile=specimen_file,dir_path=dir_path,
       iboot=1,ihext=0,ivec=1,PDir=[120,10],ipar=1, save_plots=False) # compare dike directions with plane of dike with pole of 120,10
# Out:
# desired coordinate system not available, using available:  g
# (True, [])

# %%
ipmag.aniso_magic??
# Out:
# Signature:
# ipmag.aniso_magic(
#     infile='specimens.txt',
#     samp_file='samples.txt',
#     site_file='sites.txt',
#     verbose=True,
#     ipar=False,
#     ihext=True,
#     ivec=False,
#     isite=False,
#     iboot=False,
#     vec=0,
#     Dir=[],
#     PDir=[],
#     crd='s',
#     num_bootstraps=1000,
#     dir_path='.',
#     fignum=1,
#     save_plots=True,
#     interactive=False,
#     fmt='png',
#     contribution=None,
#     image_records=False,
# )
# Source:
# def aniso_magic(infile='specimens.txt', samp_file='samples.txt', site_file='sites.txt', verbose=True,
#                 ipar=False, ihext=True, ivec=False, isite=False, iboot=False, vec=0,
#                 Dir=[], PDir=[], crd="s", num_bootstraps=1000, dir_path=".", fignum=1,
#                 save_plots=True, interactive=False, fmt="png", contribution=None, image_records=False):
#     """
#     Makes plots of anisotropy eigenvectors, eigenvalues and confidence bounds
# ...

# %%
ipmag.plot_aniso??
# Out:
# Signature:
# ipmag.plot_aniso(
#     fignum,
#     aniso_df,
#     Dir=[],
#     PDir=[],
#     ipar=False,
#     ihext=True,
#     ivec=False,
#     iboot=False,
#     vec=0,
#     num_bootstraps=1000,
#     title='',
# )
# Docstring: <no docstring>
# Source:
# def plot_aniso(fignum, aniso_df, Dir=[], PDir=[], ipar=False, ihext=True, ivec=False,
#                iboot=False, vec=0, num_bootstraps=1000, title=""):
#     figs = {}
#     ipar = int(ipar)
#     ihext = int(ihext)
#     ivec = int(ivec)
#     iboot = int(iboot)
#     Ss, V1, V2, V3 = [], [], [], []
#     for ind, rec in aniso_df.iterrows():
#         s = [float(i.strip()) for i in rec['aniso_s'].split(':')]
#         if s[0] <= 1.0:
#             Ss.append(s)  # protect against crap
#             tau, Vdir = pmag.doseigs(s)
#             V1.append([Vdir[0][0], Vdir[0][1]])
#             V2.append([Vdir[1][0], Vdir[1][1]])
#             V3.append([Vdir[2][0], Vdir[2][1]])
#     Ss = np.array(Ss)
#     if Ss.shape[0] > 1:
# ...

# %%
# Load Anisotropy of Magnetic Susceptibility Data
data_file = ''  # replace with your data file path
ams_data = pd.read_csv(data_file)

# Display the first few rows of the data
ams_data.head()

# %% [markdown]
# # Analyze Data with ipmag.aniso_magic
# Use the ipmag.aniso_magic function to analyze the loaded data.

# %%
# Analyze Data with ipmag.aniso_magic
aniso_results = ipmag.aniso_magic(ams_data)

# Display the results
aniso_results.head()
