# %% [markdown]
# # Backfield processing
#
# This notebook processes rock magnetic backfield demagnetization data with the primary purpose of obtaining B<sub>cr</sub> (coercivity of remanence) values.

# %%
import pmagpy.rockmag as rmag

import pmagpy.ipmag as ipmag
import pmagpy.pmag as pmag
import pmagpy.contribution_builder as cb
import pandas as pd
import matplotlib.pyplot as plt 

from bokeh.io import output_notebook
output_notebook(hide_banner=True)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Import data

# %%
# define the path to the folder 
dir_path = '../example_data/SSRM2024C'
# download the data from the MagIC database using my private contribution key 
result, magic_file = ipmag.download_magic_from_id('20433', directory=dir_path, share_key='e0bc04fd-8725-4aff-8687-75d51e741bcc')
# unpack the MagIC file
ipmag.unpack_magic(magic_file, dir_path, print_progress=False)
# get the contribution object
contribution = cb.Contribution(dir_path)
# get the measurements table
measurements = contribution.tables['measurements'].df
measurements = measurements.dropna(axis=1, how='all')
specimens = contribution.tables['specimens'].df
# Out:
# Download successful. File saved to: ../example_data/SSRM2024C/magic_contribution_20433.txt
# 1  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/contribution.txt
# 1  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/locations.txt
# 16  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/sites.txt
# 28  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/samples.txt
# 50  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/specimens.txt
# 16966  records written to file  /Users/penokean/0000_GitHub/RockmagPy-notebooks/example_data/SSRM2024C/measurements.txt
# -I- Using online data model
# -I- Getting method codes from earthref.org
# -I- Importing controlled vocabularies from https://earthref.org

# %% [markdown]
# ## Select specimen backfield experiment data

# %%
# filter for the backfield data
backfield_data = measurements[measurements['method_codes'] == 'LP-BCR-BF']

# %%
# investigate the specimens that have backfield data
backfield_data['specimen'].unique()
# Out:
# <StringArray>
# ['MA1-5-r gelcap', 'MA1-OX-r', 'SJ1-4-r gelcap', 'SJ5-5-r gelcap', 'WS3-1-r']
# Length: 5, dtype: str

# %%
# select the specimen
specimen = 'SJ1-4-r gelcap'
specimen_data = backfield_data[backfield_data['specimen'] == specimen]

# investigate the available backfield experiments, sometimes multiple experiments are done on the same specimen
specimen_data['experiment'].unique()
# Out:
# <StringArray>
# ['IRM-VSM4-LP-BCR-BF-239364']
# Length: 1, dtype: str

# %%
selected_experiment = specimen_data[specimen_data['experiment'] == 'IRM-VSM4-LP-BCR-BF-239364'].reset_index()

# %% [markdown]
# ## Process backfield data

# %%
selected_experiment, Bcr = rmag.process_backfield_data(selected_experiment)
print(f"Coercivity: {round(Bcr,7)} T")
print(f"Coercivity: {round(Bcr*1000,4)} mT")
# Out:
# Coercivity: 0.0196186 T
# Coercivity: 19.6186 mT

# %%
rmag.plot_backfield_data(selected_experiment, plot_processed=False, Bcr=Bcr, interactive=True)
# Out:
#   <div id="e2094cb6-e182-4fb3-8170-c9a040546b85" data-root-id="p1135" style="display: contents;"></div>

# %% [markdown]
# ## Applying smoothing
#
# The `rmag.process_backfield_data` function can also be used to smooth the data. The code below implements such smoothing which is applied to the processed backfield which is then used to develop the coercivity spectra.

# %%
# spline smoothing with a light smoothing factor; increase smooth_frac for noisier data
selected_experiment, Bcr = rmag.process_backfield_data(selected_experiment,smooth_mode='spline',smooth_frac=0.005)
rmag.plot_backfield_data(selected_experiment, Bcr=Bcr, interactive=True)
# Out:
#   <div id="e0230c90-4d6e-48f5-a55e-43ffbfbd17be" data-root-id="p1329" style="display: contents;"></div>

# %% [markdown]
# ## Add the calculated Bcr values to the specimens data table

# %%
rmag.add_Bcr_to_specimens_table(specimens, 'IRM-VSM4-LP-BCR-BF-239364', Bcr)
specimens
# Out:
#                 azimuth                              description   dip  \
# specimen name
# HH8-1-r           181.3    Haliburton Highlands 8-1 VSM specimen  43.0
# HH8-1x            181.3    Haliburton Highlands 8-1 X-T specimen  43.0
# HH8-3b            181.3            Haliburton Highlands 8-3 core  43.0
# MA1-1b            211.7                               MA1-1 core  56.0
# MA1-2-r           222.7                       MA1-2 VSM specimen  56.0
# MA1-2b            222.7                               MA1-2 core  56.0
# MA1-2x            222.7                       MA1-2 X-T specimen  56.0
# MA1-3b            215.7                               MA1-3 core  49.0
# MA1-5-r gelcap      NaN                         gel cap for MPMS   NaN
# MA1-5b            226.7               Marcy anorthosite 1-5 core  56.0
# MA1-8b            236.7                               MA1-8 core  51.0
# MA1-OX-cube       211.7                 MA1-OX X-T cube specimen  56.0
# MA1-OX-r          211.7                      MA1-OX VSM specimen  56.0
# MA1-OX-x          211.7                      MA1-OX X-T specimen  56.0
# MA5-3-r             0.0       Marcy anorthosite 5-3 VSM specimen   0.0
# MA5-4b            289.3               Marcy anorthosite 5-4 core  64.0
# SJ1-1b            181.5                         St Jean 1-1 core  48.0
# SJ1-1x            181.5                         St Jean 1-1 core  48.0
# SJ1-2b            189.5                               SJ1-2 core  50.0
# SJ1-3-r           179.5                       SJ1-3 VSM specimen  55.0
# SJ1-3b            179.5                               SJ1-3 core  55.0
# SJ1-3x            179.5                       SJ1-3 X-T specimen  55.0
# SJ1-4-r gelcap      NaN                         gel cap for MPMS   NaN
# SJ1-5b            174.5                               SJ1-5 core  36.0
# SJ1-5x            174.5                       SJ1-5 X-T specimen  36.0
# SJ5-5-r gelcap      NaN                         gel cap for MPMS   NaN
# SJ5-5b             38.9                         St Jean 5-4 core  47.0
# TH1-1b             77.6                   Thanet gabbro 1-1 core  17.0
# TH1-2-r             0.0               Thanet gabbro 1-2 VSM core   0.0
# WS3-1-r            11.6  Whitestone anorthosite 3-1 VSM specimen  69.0
# WS3-1b             11.6          Whitestone anorthosite 3-1 core  69.0
# WS3-1x             11.6  Whitestone anorthosite 3-1 X-T specimen  69.0
# WS9-1-r           308.7      Whitestone anorthosite 9-1 VSM core  48.0
# WS9-1b            308.7          Whitestone anorthosite 9-1 core  48.0
# HH8-1-r             NaN                                      NaN   NaN
# MA1-5-r gelcap      NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# SJ1-4-r gelcap      NaN                                      NaN   NaN
# SJ5-5-r gelcap      NaN                                      NaN   NaN
# TH1-2-r             NaN                                      NaN   NaN
# WS3-1-r             NaN                                      NaN   NaN
# MA1-5-r gelcap      NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# MA1-OX-r            NaN                                      NaN   NaN
# SJ1-4-r gelcap      NaN                                      NaN   NaN
# SJ5-5-r gelcap      NaN                                      NaN   NaN
# WS3-1-r             NaN                                      NaN   NaN
#
#                               experiments   hyst_bc  hyst_bc_offset  hyst_bcr  \
# specimen name
# HH8-1-r                               NaN       NaN             NaN       NaN
# HH8-1x                                NaN       NaN             NaN       NaN
# HH8-3b                                NaN       NaN             NaN       NaN
# MA1-1b                                NaN       NaN             NaN       NaN
# MA1-2-r                               NaN       NaN             NaN       NaN
# MA1-2b                                NaN       NaN             NaN       NaN
# MA1-2x                                NaN       NaN             NaN       NaN
# MA1-3b                                NaN       NaN             NaN       NaN
# MA1-5-r gelcap                        NaN       NaN             NaN       NaN
# MA1-5b                                NaN       NaN             NaN       NaN
# MA1-8b                                NaN       NaN             NaN       NaN
# MA1-OX-cube                           NaN       NaN             NaN       NaN
# MA1-OX-r                              NaN       NaN             NaN       NaN
# MA1-OX-x                              NaN       NaN             NaN       NaN
# MA5-3-r                               NaN       NaN             NaN       NaN
# MA5-4b                                NaN       NaN             NaN       NaN
# SJ1-1b                                NaN       NaN             NaN       NaN
# SJ1-1x                                NaN       NaN             NaN       NaN
# SJ1-2b                                NaN       NaN             NaN       NaN
# SJ1-3-r                               NaN       NaN             NaN       NaN
# SJ1-3b                                NaN       NaN             NaN       NaN
# SJ1-3x                                NaN       NaN             NaN       NaN
# SJ1-4-r gelcap                        NaN       NaN             NaN       NaN
# SJ1-5b                                NaN       NaN             NaN       NaN
# SJ1-5x                                NaN       NaN             NaN       NaN
# SJ5-5-r gelcap                        NaN       NaN             NaN       NaN
# SJ5-5b                                NaN       NaN             NaN       NaN
# TH1-1b                                NaN       NaN             NaN       NaN
# TH1-2-r                               NaN       NaN             NaN       NaN
# WS3-1-r                               NaN       NaN             NaN       NaN
# WS3-1b                                NaN       NaN             NaN       NaN
# WS3-1x                                NaN       NaN             NaN       NaN
# WS9-1-r                               NaN       NaN             NaN       NaN
# WS9-1b                                NaN       NaN             NaN       NaN
# HH8-1-r            IRM-VSM3-LP-HYS-239366  0.385700   -1.135000e-02       NaN
# MA1-5-r gelcap     IRM-VSM3-LP-HYS-239371  0.003126    2.087000e-04       NaN
# MA1-OX-r           IRM-VSM3-LP-HYS-239373  0.009699    1.141000e-04       NaN
# MA1-OX-r           IRM-VSM4-LP-HYS-239361  0.009273   -1.335000e-04       NaN
# MA1-OX-r           IRM-VSM4-LP-HYS-239360  0.009273   -1.335000e-04       NaN
# MA1-OX-r           IRM-VSM4-LP-HYS-239377  0.008366   -1.466000e-04       NaN
# SJ1-4-r gelcap     IRM-VSM4-LP-HYS-239362  0.005387   -5.115000e-05       NaN
# SJ5-5-r gelcap     IRM-VSM3-LP-HYS-239368  0.003830    1.238000e-04       NaN
# TH1-2-r            IRM-VSM4-LP-HYS-239383  0.009204    1.397000e-10       NaN
# WS3-1-r            IRM-VSM3-LP-HYS-239367  0.001666    1.163000e-04       NaN
# MA1-5-r gelcap  IRM-VSM3-LP-BCR-BF-239370       NaN             NaN    0.0311
# MA1-OX-r        IRM-VSM3-LP-BCR-BF-239372       NaN             NaN    0.0537
# MA1-OX-r        IRM-VSM4-LP-BCR-BF-239379       NaN             NaN    0.0600
# SJ1-4-r gelcap  IRM-VSM4-LP-BCR-BF-239364       NaN             NaN    0.0196
# SJ5-5-r gelcap  IRM-VSM3-LP-BCR-BF-239369       NaN             NaN    0.0152
# WS3-1-r         IRM-VSM3-LP-BCR-BF-239374       NaN             NaN    0.0110
#
#                 hyst_mr_mass  hyst_ms_mass      hyst_xhf  ... rem_hirm_mass  \
# specimen name                                             ...
# HH8-1-r                  NaN           NaN           NaN  ...           NaN
# HH8-1x                   NaN           NaN           NaN  ...           NaN
# HH8-3b                   NaN           NaN           NaN  ...           NaN
# MA1-1b                   NaN           NaN           NaN  ...           NaN
# MA1-2-r                  NaN           NaN           NaN  ...           NaN
# MA1-2b                   NaN           NaN           NaN  ...           NaN
# MA1-2x                   NaN           NaN           NaN  ...           NaN
# MA1-3b                   NaN           NaN           NaN  ...           NaN
# MA1-5-r gelcap           NaN           NaN           NaN  ...           NaN
# MA1-5b                   NaN           NaN           NaN  ...           NaN
# MA1-8b                   NaN           NaN           NaN  ...           NaN
# MA1-OX-cube              NaN           NaN           NaN  ...           NaN
# MA1-OX-r                 NaN           NaN           NaN  ...           NaN
# MA1-OX-x                 NaN           NaN           NaN  ...           NaN
# MA5-3-r                  NaN           NaN           NaN  ...           NaN
# MA5-4b                   NaN           NaN           NaN  ...           NaN
# SJ1-1b                   NaN           NaN           NaN  ...           NaN
# SJ1-1x                   NaN           NaN           NaN  ...           NaN
# SJ1-2b                   NaN           NaN           NaN  ...           NaN
# SJ1-3-r                  NaN           NaN           NaN  ...           NaN
# SJ1-3b                   NaN           NaN           NaN  ...           NaN
# SJ1-3x                   NaN           NaN           NaN  ...           NaN
# SJ1-4-r gelcap           NaN           NaN           NaN  ...           NaN
# SJ1-5b                   NaN           NaN           NaN  ...           NaN
# SJ1-5x                   NaN           NaN           NaN  ...           NaN
# SJ5-5-r gelcap           NaN           NaN           NaN  ...           NaN
# SJ5-5b                   NaN           NaN           NaN  ...           NaN
# TH1-1b                   NaN           NaN           NaN  ...           NaN
# TH1-2-r                  NaN           NaN           NaN  ...           NaN
# WS3-1-r                  NaN           NaN           NaN  ...           NaN
# WS3-1b                   NaN           NaN           NaN  ...           NaN
# WS3-1x                   NaN           NaN           NaN  ...           NaN
# WS9-1-r                  NaN           NaN           NaN  ...           NaN
# WS9-1b                   NaN           NaN           NaN  ...           NaN
# HH8-1-r             0.000031     -0.000434  1.546000e-07  ...           NaN
# MA1-5-r gelcap      0.002624      0.118800  2.125000e-08  ...           NaN
# MA1-OX-r            0.117200      0.829900  1.039000e-06  ...           NaN
# MA1-OX-r            0.113600      0.907100  1.014000e-06  ...           NaN
# MA1-OX-r            0.113600      0.907100  1.014000e-06  ...           NaN
# MA1-OX-r            0.135500      0.906200  1.013000e-06  ...           NaN
# SJ1-4-r gelcap      0.002785      0.068540  6.427000e-09  ...           NaN
# SJ5-5-r gelcap      0.079200      2.135000  1.985000e-07  ...           NaN
# TH1-2-r             0.010700      0.086650  1.232000e-07  ...           NaN
# WS3-1-r             0.081580      5.388000  2.708000e-07  ...           NaN
# MA1-5-r gelcap      0.002470           NaN           NaN  ...      0.000000
# MA1-OX-r            0.120400           NaN           NaN  ...      0.000000
# MA1-OX-r            0.135800           NaN           NaN  ...      0.012450
# SJ1-4-r gelcap      0.002780           NaN           NaN  ...      0.000027
# SJ5-5-r gelcap      0.079250           NaN           NaN  ...      0.000000
# WS3-1-r             0.080810           NaN           NaN  ...      0.000000
#
#                 rem_sratio  rem_sratio_back  rem_sratio_forward  \
# specimen name
# HH8-1-r                NaN              NaN                 NaN
# HH8-1x                 NaN              NaN                 NaN
# HH8-3b                 NaN              NaN                 NaN
# MA1-1b                 NaN              NaN                 NaN
# MA1-2-r                NaN              NaN                 NaN
# MA1-2b                 NaN              NaN                 NaN
# MA1-2x                 NaN              NaN                 NaN
# MA1-3b                 NaN              NaN                 NaN
# MA1-5-r gelcap         NaN              NaN                 NaN
# MA1-5b                 NaN              NaN                 NaN
# MA1-8b                 NaN              NaN                 NaN
# MA1-OX-cube            NaN              NaN                 NaN
# MA1-OX-r               NaN              NaN                 NaN
# MA1-OX-x               NaN              NaN                 NaN
# MA5-3-r                NaN              NaN                 NaN
# MA5-4b                 NaN              NaN                 NaN
# SJ1-1b                 NaN              NaN                 NaN
# SJ1-1x                 NaN              NaN                 NaN
# SJ1-2b                 NaN              NaN                 NaN
# SJ1-3-r                NaN              NaN                 NaN
# SJ1-3b                 NaN              NaN                 NaN
# SJ1-3x                 NaN              NaN                 NaN
# SJ1-4-r gelcap         NaN              NaN                 NaN
# SJ1-5b                 NaN              NaN                 NaN
# SJ1-5x                 NaN              NaN                 NaN
# SJ5-5-r gelcap         NaN              NaN                 NaN
# SJ5-5b                 NaN              NaN                 NaN
# TH1-1b                 NaN              NaN                 NaN
# TH1-2-r                NaN              NaN                 NaN
# WS3-1-r                NaN              NaN                 NaN
# WS3-1b                 NaN              NaN                 NaN
# WS3-1x                 NaN              NaN                 NaN
# WS9-1-r                NaN              NaN                 NaN
# WS9-1b                 NaN              NaN                 NaN
# HH8-1-r                NaN              NaN                 NaN
# MA1-5-r gelcap         NaN              NaN                 NaN
# MA1-OX-r               NaN              NaN                 NaN
# MA1-OX-r               NaN              NaN                 NaN
# MA1-OX-r               NaN              NaN                 NaN
# MA1-OX-r               NaN              NaN                 NaN
# SJ1-4-r gelcap         NaN              NaN                 NaN
# SJ5-5-r gelcap         NaN              NaN                 NaN
# TH1-2-r                NaN              NaN                 NaN
# WS3-1-r                NaN              NaN                 NaN
# MA1-5-r gelcap       0.000              0.1                 1.0
# MA1-OX-r             0.113              0.1                 1.0
# MA1-OX-r             0.083              0.1                 1.8
# SJ1-4-r gelcap       0.894              0.1                 1.8
# SJ5-5-r gelcap       0.000              0.1                 1.0
# WS3-1-r              0.940              0.1                 1.0
#
#                result_quality   sample        specimen    volume    weight  \
# specimen name
# HH8-1-r                     g    HH8-3         HH8-1-r  0.000001  0.000072
# HH8-1x                      g    HH8-3          HH8-1x  0.000001  0.000181
# HH8-3b                      g    HH8-3          HH8-3b  0.000000  0.000000
# MA1-1b                      g    MA1-1          MA1-1b  0.000000  0.015202
# MA1-2-r                     g    MA1-2         MA1-2-r  0.000001  0.000081
# MA1-2b                      g    MA1-2          MA1-2b  0.000000  0.015471
# MA1-2x                      g    MA1-2          MA1-2x  0.000001  0.000146
# MA1-3b                      g    MA1-3          MA1-3b  0.000000  0.015741
# MA1-5-r gelcap              g  MA1-5-r  MA1-5-r gelcap  0.000000  0.000090
# MA1-5b                      g    MA1-5          MA1-5b  0.000000  0.000000
# MA1-8b                      g    MA1-8          MA1-8b  0.000000  0.015539
# MA1-OX-cube                 g    MA1-1     MA1-OX-cube  0.000001  0.011767
# MA1-OX-r                    g    MA1-1        MA1-OX-r  0.000001  0.000113
# MA1-OX-x                    g    MA1-1        MA1-OX-x  0.000001  0.000205
# MA5-3-r                     g    MA5-4         MA5-3-r  0.000001  0.000090
# MA5-4b                      g    MA5-4          MA5-4b  0.000000  0.000000
# SJ1-1b                      g    SJ1-1          SJ1-1b  0.000000  0.000000
# SJ1-1x                      g    SJ1-1          SJ1-1x  0.000001  0.000000
# SJ1-2b                      g    SJ1-2          SJ1-2b  0.000000  0.016136
# SJ1-3-r                     g    SJ1-3         SJ1-3-r  0.000001  0.000089
# SJ1-3b                      g    SJ1-3          SJ1-3b  0.000000  0.016219
# SJ1-3x                      g    SJ1-3          SJ1-3x  0.000001  0.000086
# SJ1-4-r gelcap              g  SJ1-4-r  SJ1-4-r gelcap  0.000000  0.000069
# SJ1-5b                      g    SJ1-5          SJ1-5b  0.000000  0.013974
# SJ1-5x                      g    SJ1-5          SJ1-5x  0.000001  0.000062
# SJ5-5-r gelcap              g  SJ5-5-r  SJ5-5-r gelcap  0.000000  0.000143
# SJ5-5b                      g    SJ5-5          SJ5-5b  0.000000  0.000000
# TH1-1b                      g    TH1-1          TH1-1b  0.000000  0.000000
# TH1-2-r                     g    TH1-1         TH1-2-r  0.000001  0.000087
# WS3-1-r                     g    WS3-1         WS3-1-r  0.000001  0.000093
# WS3-1b                      g    WS3-1          WS3-1b  0.000000  0.000000
# WS3-1x                      g    WS3-1          WS3-1x  0.000001  0.000083
# WS9-1-r                     g    WS9-1         WS9-1-r  0.000001  0.000176
# WS9-1b                      g    WS9-1          WS9-1b  0.000000  0.000000
# HH8-1-r                   NaN    HH8-3         HH8-1-r       NaN  0.000072
# MA1-5-r gelcap            NaN  MA1-5-r  MA1-5-r gelcap       NaN  0.000090
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# SJ1-4-r gelcap            NaN  SJ1-4-r  SJ1-4-r gelcap       NaN  0.000069
# SJ5-5-r gelcap            NaN  SJ5-5-r  SJ5-5-r gelcap       NaN  0.000143
# TH1-2-r                   NaN    TH1-1         TH1-2-r       NaN  0.000087
# WS3-1-r                   NaN    WS3-1         WS3-1-r       NaN  0.000093
# MA1-5-r gelcap            NaN  MA1-5-r  MA1-5-r gelcap       NaN  0.000090
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# MA1-OX-r                  NaN    MA1-1        MA1-OX-r       NaN  0.000113
# SJ1-4-r gelcap            NaN  SJ1-4-r  SJ1-4-r gelcap       NaN  0.000069
# SJ5-5-r gelcap            NaN  SJ5-5-r  SJ5-5-r gelcap       NaN  0.000143
# WS3-1-r                   NaN    WS3-1         WS3-1-r       NaN  0.000093
#
#                  rem_bcr
# specimen name
# HH8-1-r              NaN
# HH8-1x               NaN
# HH8-3b               NaN
# MA1-1b               NaN
# MA1-2-r              NaN
# MA1-2b               NaN
# MA1-2x               NaN
# MA1-3b               NaN
# MA1-5-r gelcap       NaN
# MA1-5b               NaN
# MA1-8b               NaN
# MA1-OX-cube          NaN
# MA1-OX-r             NaN
# MA1-OX-x             NaN
# MA5-3-r              NaN
# MA5-4b               NaN
# SJ1-1b               NaN
# SJ1-1x               NaN
# SJ1-2b               NaN
# SJ1-3-r              NaN
# SJ1-3b               NaN
# SJ1-3x               NaN
# SJ1-4-r gelcap       NaN
# SJ1-5b               NaN
# SJ1-5x               NaN
# SJ5-5-r gelcap       NaN
# SJ5-5b               NaN
# TH1-1b               NaN
# TH1-2-r              NaN
# WS3-1-r              NaN
# WS3-1b               NaN
# WS3-1x               NaN
# WS9-1-r              NaN
# WS9-1b               NaN
# HH8-1-r              NaN
# MA1-5-r gelcap       NaN
# MA1-OX-r             NaN
# MA1-OX-r             NaN
# MA1-OX-r             NaN
# MA1-OX-r             NaN
# SJ1-4-r gelcap       NaN
# SJ5-5-r gelcap       NaN
# TH1-2-r              NaN
# WS3-1-r              NaN
# MA1-5-r gelcap       NaN
# MA1-OX-r             NaN
# MA1-OX-r             NaN
# SJ1-4-r gelcap  0.019619
# SJ5-5-r gelcap       NaN
# WS3-1-r              NaN
#
# [50 rows x 25 columns]

# %% [markdown]
# ## Overwrite the specimens data table

# %%
pmag.magic_write(dir_path + '/specimens.txt', specimens, 'specimens', dataframe=True)
# Out:
# 50  records written to file  ../example_data/SSRM2024C/specimens.txt
# (True, '../example_data/SSRM2024C/specimens.txt')

# %% [markdown]
# ## Export MagIC upload files

# %%
# ipmag.upload_magic(dir_path=dir_path,input_dir_path=dir_path, verbose=False)
